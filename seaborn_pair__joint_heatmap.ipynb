# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("market_satis.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.columns = ["fatura_id" , "sube" , "sehir" , "müsteri_tipi" , "cinsiyet" , "urun_hatti" , "birim_fiyat" , "miktar" ,
             "vergi %5" , "total" , "tarih" , "saat" , "odeme" , "maliyet" , "brüt_kar_marjı_yüzdesi" ,"brut_gelir","puanlama"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fatura_id               1000 non-null   object
#  1   sube                    1000 non-null   object
#  2   sehir                   1000 non-null   object
#  3   müsteri_tipi            1000 non-null   object
#  4   cinsiyet                1000 non-null   object
#  5   urun_hatti              1000 non-null   object
#  6   birim_fiyat             1000 non-null   float64
#  7   miktar                  1000 non-null   int64
#  8   vergi %5                1000 non-null   float64
#  9   total                   1000 non-null   float64
#  10  tarih                   1000 non-null   object
#  11  saat                    1000 non-null   object
#  12  odeme                   1000 non-null   object
#  13  maliyet                 1000 non-null   float64
# ...

# %% [markdown]
# # PAİRPLOT NEDİR ?

# %% [raw]
# Pairplot tüm veri çerçevesi boyunca, sayısal sütunlar için çift yönlü ilişkiler çizer.

# %%
plt.figure(figsize = (20,20) , dpi = 200)
sns.pairplot(df)

# %%
# yine hue komutu ile gruplandırma yapabiliriz ...

plt.figure(figsize = (20,20) , dpi = 200)
sns.pairplot(data = df.iloc[: , :12] , hue = "sube" ) # sadece sayısal sütunlar olmalı

# %%
# corner komutu ile grafiklerin sadece sol köşesini alabiliriz ...

plt.figure(figsize = (20,20) , dpi = 200)
sns.pairplot(data = df.iloc[: , :12] , hue = "sube" , corner = True )

# %% [markdown]
# # JOİNT PLOT

# %% [raw]
# Histogram ve saçılım grafiklerinin ikisinin bir arada göstrerildiği grafikler denilebilir ...

# %%
df
# Out:
#        fatura_id sube      sehir müsteri_tipi cinsiyet  \
# 0    750-67-8428    A     Yangon       Member   Female
# 1    226-31-3081    C  Naypyitaw       Normal   Female
# 2    631-41-3108    A     Yangon       Normal     Male
# 3    123-19-1176    A     Yangon       Member     Male
# 4    373-73-7910    A     Yangon       Normal     Male
# ..           ...  ...        ...          ...      ...
# 995  233-67-5758    C  Naypyitaw       Normal     Male
# 996  303-96-2227    B   Mandalay       Normal   Female
# 997  727-02-1313    A     Yangon       Member     Male
# 998  347-56-2442    A     Yangon       Normal     Male
# 999  849-09-3807    A     Yangon       Member   Female
#
#                  urun_hatti  birim_fiyat  miktar  vergi %5      total  \
# 0         Health and beauty        74.69       7   26.1415   548.9715
# 1    Electronic accessories        15.28       5    3.8200    80.2200
# 2        Home and lifestyle        46.33       7   16.2155   340.5255
# ...

# %%
# birim fiyat ve total fiyatın joint plotunu çizelim ...

plt.figure(figsize = (16,9) , dpi = 200)
sns.jointplot(data = df , x = "birim_fiyat" , y = "total" )

# %%
# kde grafiği olarakta çizebiliriz ...

plt.figure(figsize = (16,9) , dpi = 200)
sns.jointplot(data = df , x = "birim_fiyat" , y = "total" , kind = "kde" )

# %%
# hex grafiği : ...

plt.figure(figsize = (16,9) , dpi = 200)
sns.jointplot(data = df , x = "birim_fiyat" , y = "total" , kind = "hex")

# %% [markdown]
# # CATPLOT

# %% [raw]
# Bu işlev, birkaç görsel temsilden birini kullanarak sayısal ve bir veya daha fazla kategorik değişken arasındaki ilişkiyi
# gösteren birkaç eksen düzeyinde işleve erişim sağlar.

# %%
df
# Out:
#        fatura_id sube      sehir müsteri_tipi cinsiyet  \
# 0    750-67-8428    A     Yangon       Member   Female
# 1    226-31-3081    C  Naypyitaw       Normal   Female
# 2    631-41-3108    A     Yangon       Normal     Male
# 3    123-19-1176    A     Yangon       Member     Male
# 4    373-73-7910    A     Yangon       Normal     Male
# ..           ...  ...        ...          ...      ...
# 995  233-67-5758    C  Naypyitaw       Normal     Male
# 996  303-96-2227    B   Mandalay       Normal   Female
# 997  727-02-1313    A     Yangon       Member     Male
# 998  347-56-2442    A     Yangon       Normal     Male
# 999  849-09-3807    A     Yangon       Member   Female
#
#                  urun_hatti  birim_fiyat  miktar  vergi %5      total  \
# 0         Health and beauty        74.69       7   26.1415   548.9715
# 1    Electronic accessories        15.28       5    3.8200    80.2200
# 2        Home and lifestyle        46.33       7   16.2155   340.5255
# ...

# %%
# bar grafiği çizelim ...

plt.figure(figsize = (20,15) , dpi = 200)
sns.catplot(data = df , x = "sube" , y = "maliyet" ,  kind = "bar")

# %%
# boxplot grafiği çizelim ...

plt.figure(figsize = (20,15) , dpi = 200)
sns.catplot(data = df , x = "sube" , y = "maliyet" ,  kind = "box")

# %%
# row ve col komutları ile satır veya sütuna yayarak grafikleri gruplandırma yapabiliriz ...

plt.figure(figsize = (20,15) , dpi = 200)
sns.catplot(data = df , x = "sube" , y = "maliyet" ,  kind = "box" , row = "cinsiyet")

# %%
plt.figure(figsize = (20,15) , dpi = 200)
sns.catplot(data = df , x = "sube" , y = "maliyet" ,  kind = "box" , col = "cinsiyet")

# %% [markdown]
# # HEATMAP

# %% [raw]
# Heatmap (Isı haritası) , bir veri kümesindeki bireysel değerlerin büyüklüğünü bir renk olarak temsil eden 2 boyutlu bir veri
# görselleştirme tekniğidir.

# %%
df = pd.read_csv("Berlin_crimes.csv") # berlindeki suçlar

# %%
df
# Out:
#       Year       District    Code                                Location  \
# 0     2012          Mitte   10111                          Tiergarten Süd
# 1     2012          Mitte   10112                       Regierungsviertel
# 2     2012          Mitte   10113                          Alexanderplatz
# 3     2012          Mitte   10114                       Brunnenstraße Süd
# 4     2012          Mitte   10221                             Moabit West
# ...    ...            ...     ...                                     ...
# 1195  2019  Reinickendorf  123012  Nord 2 - Waidmannslust/Wittenau/Lübars
# 1196  2019  Reinickendorf  123021               MV 1 - Märkisches Viertel
# 1197  2019  Reinickendorf  123022                 MV 2 - Rollbergsiedlung
# 1198  2019  Reinickendorf  123043      West 3 - Borsigwalde/Freie Scholle
# 1199  2019  Reinickendorf  129900           Bezirk (Rd), nicht zuzuordnen
#
#       Robbery  Street_robbery  Injury  Agg_assault  Threat  Theft  Car  \
# ...

# %%
df.columns = ["yıl" , "semt" , "kod" , "lokasyon" , "soygun" , "sokak_soygunlari" , "yaralanma" , "toplu_saldiri" , "tehdit" , 
             "calinma" , "araba" , "arabadan_calinma" , "bisiklet" ,  "hirsizlik" ,"yangin" , "kundakcilik", "zarar" , "duvar_yazisi" 
             , "ilaclar" , "yerel"]

# %%
df
# Out:
#        yıl           semt     kod                                lokasyon  \
# 0     2012          Mitte   10111                          Tiergarten Süd
# 1     2012          Mitte   10112                       Regierungsviertel
# 2     2012          Mitte   10113                          Alexanderplatz
# 3     2012          Mitte   10114                       Brunnenstraße Süd
# 4     2012          Mitte   10221                             Moabit West
# ...    ...            ...     ...                                     ...
# 1195  2019  Reinickendorf  123012  Nord 2 - Waidmannslust/Wittenau/Lübars
# 1196  2019  Reinickendorf  123021               MV 1 - Märkisches Viertel
# 1197  2019  Reinickendorf  123022                 MV 2 - Rollbergsiedlung
# 1198  2019  Reinickendorf  123043      West 3 - Borsigwalde/Freie Scholle
# 1199  2019  Reinickendorf  129900           Bezirk (Rd), nicht zuzuordnen
#
#       soygun  sokak_soygunlari  yaralanma  toplu_saldiri  tehdit  calinma  \
# ...

# %%
sayisal_bolumler = df[["soygun" , "sokak_soygunlari" , "yaralanma" , "toplu_saldiri" , "tehdit" , "calinma" , "araba" , 
                       "arabadan_calinma" , "bisiklet" , "hirsizlik" , "yangin" , "kundakcilik" , "zarar" , "duvar_yazisi" ,
                      "ilaclar" , "yerel"]]

# %%
sayisal_bolumler
# Out:
#       soygun  sokak_soygunlari  yaralanma  toplu_saldiri  tehdit  calinma  \
# 0         70                46        586            194     118     2263
# 1         65                29        474            123     142     3203
# 2        242               136       1541            454     304     8988
# 3         52                25        254             60      66     1916
# 4        130                51        629            185     199     2470
# ...      ...               ...        ...            ...     ...      ...
# 1195      34                19        372             85     123     1160
# 1196      42                22        491            123     187     1100
# 1197       6                 4         84             19      34      293
# 1198       8                 4         95             18      43      492
# 1199       3                 2         14              7       4       59
#
#       araba  arabadan_calinma  bisiklet  hirsizlik  yangin  kundakcilik  \
# ...

# %%
# korelasyon tablosunu heatmap ile çizelim

korelasyon = sayisal_bolumler.corr()
korelasyon
# Out:
#                     soygun  sokak_soygunlari  yaralanma  toplu_saldiri  \
# soygun            1.000000          0.965608   0.844837       0.883106
# sokak_soygunlari  0.965608          1.000000   0.784158       0.837524
# yaralanma         0.844837          0.784158   1.000000       0.967405
# toplu_saldiri     0.883106          0.837524   0.967405       1.000000
# tehdit            0.777466          0.692007   0.915159       0.851831
# calinma           0.815009          0.765908   0.869828       0.855720
# araba             0.342169          0.290983   0.431050       0.344605
# arabadan_calinma  0.675264          0.606269   0.712120       0.663261
# bisiklet          0.648652          0.618891   0.652590       0.658315
# hirsizlik         0.543606          0.457082   0.521500       0.499268
# yangin            0.654357          0.600143   0.747471       0.701673
# kundakcilik       0.597664          0.544589   0.662397       0.635040
# ...

# %%
plt.figure(figsize = (20,15) , dpi = 200)
sns.heatmap(korelasyon)
# Out:
# <AxesSubplot:>

# %%
# cmap komutu ile renkleri daha açık yapabiliriz ...

plt.figure(figsize = (20,15) , dpi = 200)
sns.heatmap(korelasyon , cmap = "magma")
# Out:
# <AxesSubplot:>

# %%
# lw komutu ile çizgileri kalınlaştırabiliriz ...

plt.figure(figsize = (20,15) , dpi = 200)
sns.heatmap(korelasyon , cmap = "magma" , lw = 0.5)
# Out:
# <AxesSubplot:>

# %%
# annot komutu ile değerleri kutucukların içine yazdırabiliriz ...

plt.figure(figsize = (20,15) , dpi = 200)
sns.heatmap(korelasyon , cmap = "magma" , lw = 0.5 , annot = True)
# Out:
# <AxesSubplot:>

# %%
# fmt komutu ile değerleri tam sayıya yuvarlayabiliriz ...

plt.figure(figsize = (20,15) , dpi = 200)
sns.heatmap(korelasyon , cmap = "magma" , lw = 0.5 , annot = True , fmt = ".0f")
# Out:
# <AxesSubplot:>

# %%
# center komutu ile kutucukların içini koyulaştırabiliriz ...

plt.figure(figsize = (20,15) , dpi = 200)
sns.heatmap(korelasyon , cmap = "magma" , lw = 0.5 , annot = True , center = 1)
# Out:
# <AxesSubplot:>
